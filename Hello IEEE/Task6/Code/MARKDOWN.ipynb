# %% [markdown]
# Normal Equation imp:
# 1) The model learns in a single caluclation, which is really good for small data sets but impractical for large amounts of data.
# 2) I did not need to normalize the values before implementing it, and since the data was well-generated, there was no divide by 0 sitatuion in the matrix inverse calucatation.
# 3) calucating inverse becomes extremely slow for big data.
# 4) it provides the exact theoritical min.

# %% [markdown]
# Gradient imp:
# 1) It uses iterative optimzation to loop gradually towards the local minimum.
# 2) needs feature scaling else the algo would diverge due to abs value of some of the features tht have big values in its nature like total_rooms
# 3) I had to manually choose a learning rate ( googled which worked best tbh )
# 4) slower for smaller data sets but extremely faster for large ones
